# %%
import numpy as np
import matplotlib.pyplot as plt
import math 

def f(x):
    return np.sin(x) + 0.5 * x
x = np.linspace(-2* np.pi, 2* np.pi, 50)

plt.plot(x, f(x), 'b')
plt.grid(True)

# %%
reg = np.polyfit(x, f(x), deg=1)
ry = np.polyval(reg, x)

# %%
plt.plot(x,f(x),'b', label='f(x)')
plt.plot(x,ry, 'r', label='regression')
plt.legend(loc=0)
plt.grid(True)
plt.xlabel('x')
plt.ylabel('f(x)')
# Out:
# Text(0, 0.5, 'f(x)')

# %%
reg = np.polyfit(x, f(x), deg=5)
ry = np.polyval(reg, x)

# %%
plt.plot(x, f(x), 'b', label='f(x)')
plt.plot(x, ry, 'r', label='regression')
plt.legend(loc=0)
plt.grid(True)
plt.xlabel('x')
plt.ylabel('f(x)')
# Out:
# Text(0, 0.5, 'f(x)')

# %%
np.polyfit(x, f(x), deg= 5)
ry = np.polyval(reg, x)

# %%
plt.plot(x, f(x), 'b', label='f(x)')
plt.plot(x, ry, 'r', label='regression')
plt.legend(loc=0)
plt.grid(True)
plt.xlabel('x')
plt.ylabel('f(x)')
# Out:
# Text(0, 0.5, 'f(x)')

# %%
np.allclose(f(x), ry)
# Out:
# False

# %%
np.sum(f(x)- ry)** 2/ len(x)
# Out:
# 4.589993340004279e-29

# %%
plt.plot(x, f(x), 'b', label='f(x)')
plt.plot(x, ry, 'r.', label ='regression')
plt.legend(loc=0)
plt.grid(True)
plt.xlabel('x')
plt.ylabel('f(x)')
# Out:
# Text(0, 0.5, 'f(x)')

# %%
plt.plot(x, f(x), 'b', label='f(x)')
plt.plot(x, ry, 'r',label='regresion')
plt.legend(loc=0)
plt.grid(True)
plt.xlabel('x')
plt.ylabel('f(x)')
# Out:
# Text(0, 0.5, 'f(x)')

# %%
np.allclose(f(x), ry)
# Out:
# False

# %%
np.sum((f(x) - ry)**2) /len(x)
# Out:
# 0.053882515523087385

# %%
def fm(x, y):
    return np.sin(x) + 0.25 * x + np.sqrt(y) + 0.05 * y ** 2

# %%
x = np.linspace(0,10,20)
y = np.linspace(0,10,20)
X, Y = np.meshgrid(x, y)

# %%
Z = fm(X,Y)
x = x.flatten()
y = Y.flatten()

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib as mpl

# %%
fig = plt.figure(figsize=(9,6))
ax = fig.gca(projection ='3d')
surf = ax.plot_surface(X, Y, Z, rstride = 2, cstride =2,
                       cmap=mpl.cm.coolwarm,
                       linewidth=0.5, antialiased=True)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('f(x, y)')
fig.colorbar(surf, shrink=0.5, aspect=5)
